# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesht007/Threepio_auto_command_mapping/blob/main/json_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aa40ec7b-c5d1-4988-997a-3edb83b34847" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa40ec7b-c5d1-4988-997a-3edb83b34847">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapped_commands_full.json to mapped_commands_full.json

# %%
import json

with open('mapped_commands_full.json') as json_file:
    data = json.load(json_file)
print(data)
# Out:
# {'tf': {'load_op_library': [{'args': [{'name': 'library_filename', 'kwarg': False, 'opt': False}], 'attrs': ['tf', 'load_op_library'], 'name': 'load_op_library'}], 'map_fn': [{'args': [{'name': 'fn', 'kwarg': False, 'opt': False}, {'name': 'elems', 'kwarg': False, 'opt': False}, {'name': 'dtype', 'kwarg': True, 'opt': True}, {'name': 'parallel_iterations', 'kwarg': True, 'opt': True}, {'name': 'back_prop', 'kwarg': True, 'opt': True}, {'name': 'swap_memory', 'kwarg': True, 'opt': True}, {'name': 'infer_shape', 'kwarg': True, 'opt': True}, {'name': 'name', 'kwarg': True, 'opt': True}], 'attrs': ['tf', 'map_fn'], 'name': 'map_fn'}], 'linspace': [{'args': [{'name': 'start', 'kwarg': False, 'opt': False, 'torch': 'start', 'tfjs': 'start'}, {'name': 'stop', 'kwarg': False, 'opt': False, 'tfjs': 'stop'}, {'name': 'num', 'kwarg': False, 'opt': False, 'tfjs': 'num'}, {'name': 'name', 'kwarg': True, 'opt': True}], 'attrs': ['tf', 'linspace'], 'name': 'linspace', 'torch': 'linspace', 'tfjs': '
# ...

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(type(data['tf']))
# Out:
# <class 'dict'>

# %%
for commands in data['tf']:
  print(commands)
# Out:
# load_op_library
# map_fn
# linspace
# is_tensor
# make_ndarray
# load_library
# make_tensor_proto
# identity_n
# indexedslices
# indexedslicesspec
# hessians
# jit_scope
# histogram_fixed_width_bins
# identity
# histogram_fixed_width
# compile
# enable_mixed_precision_graph_rewrite
# disable_mixed_precision_graph_rewrite
# load_variable
# latest_checkpoint
# list_variables
# load_checkpoint
# get_checkpoint_state
# exponentialmovingaverage
# checkpoints_iterator
# coordinator
# checkpoint
# checkpointmanager
# clusterspec
# initialize_tpu_system
# shutdown_tpu_system
# deviceassignment
# failureexception
# main
# testcase
# is_built_with_gpu_support
# is_built_with_rocm
# gpu_device_name
# is_built_with_cuda
# create_local_cluster
# compute_gradient
# is_gpu_available
# benchmark_config
# benchmark
# assert_equal_graph_def
# get_link_flags
# get_include
# get_lib
# get_compile_flags
# write_raw_pb
# set_step
# get_step
# trace_off
# write
# text
# trace_export
# trace_on
# scalar
# ...

# %%
for commands in data['torch']:
  print(commands)
# Out:
# from_dlpack
# to_dlpack
# load_url
# cppextension
# cudaextension
# buildextension
# load
# load_inline
# include_paths
# check_compiler_abi_compatibility
# verify_ninja_availability
# get_worker_info
# random_split
# checkpoint
# checkpoint_sequential
# addmm
# mm
# sum
# init_rpc
# rpc_sync
# rpc_async
# remote
# shutdown
# fork_rng
# get_rng_state
# initial_seed
# manual_seed
# seed
# set_rng_state
# quantize
# export
# calculate_gain
# uniform_
# normal_
# quantize_dynamic
# quantize_qat
# prepare
# prepare_qat
# convert
# add_quant_dequant
# add_observer_
# swap_module
# propagate_qconfig_
# default_eval_fn
# get_observer_dict
# relu
# linear
# conv2d
# conv3d
# max_pool2d
# adaptive_avg_pool2d
# avg_pool2d
# interpolate
# upsample
# upsample_bilinear
# upsample_nearest
# register_custom_op_symbolic
# shape_as_tensor
# set_training
# is_in_onnx_export
# list
# help
# download_url_to_file
# load_state_dict_from_url
# set_dir
# is_initialized
# constant_
# ones_
# zeros_
# eye_
# ...

# %%
for commands in data['tfjs']:
  print(commands)
# Out:
# tensor
# scalar
# tensor1d
# tensor2d
# tensor3d
# tensor4d
# tensor5d
# tensor6d
# buffer
# clone
# complex
# eye
# fill
# imag
# linspace
# onehot
# ones
# oneslike
# print
# range
# real
# truncatednormal
# variable
# zeros
# zeroslike
# flatten
# asscalar
# as1d
# as2d
# as3d
# as4d
# as5d
# astype
# buffersync
# array
# arraysync
# data
# datasync
# dispose
# tofloat
# toint
# tobool
# reshape
# reshapeas
# expanddims
# cumsum
# squeeze
# tostring
# assign
# set
# get
# totensor
# batchtospacend
# broadcastto
# cast
# depthtospace
# pad
# setdiff1dasync
# spacetobatchnd
# booleanmaskasync
# concat
# gather
# reverse
# slice
# split
# stack
# tile
# unstack
# multinomial
# randomgamma
# randomnormal
# randomuniform
# sequential
# model
# input
# loadgraphmodel
# loadlayersmodel
# browserdownloads
# browserfiles
# http
# copymodel
# listmodels
# movemodel
# removemodel
# registerclass
# predict
# execute
# executeasync
# summary
# compile
# evaluate
# evaluatedataset
# ...
