# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesht007/Threepio_auto_command_mapping/blob/main/json_test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-059bdb36-ba2b-49a8-b484-2facbc827ee7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-059bdb36-ba2b-49a8-b484-2facbc827ee7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapped_commands_full.json to mapped_commands_full.json

# %%
import json

with open('mapped_commands_full.json') as json_file:
    data = json.load(json_file)
    tf = data['tf']
    # print("tf:", data['tf'])

# %%
print(type(data))
print(type(tf))
# Out:
# <class 'dict'>
# <class 'dict'>

# %%
for key, value in tf.items():
        print(key, ":", value)
# Out:
# load_op_library : [{'args': [{'name': 'library_filename', 'kwarg': False, 'opt': False}], 'attrs': ['tf', 'load_op_library'], 'name': 'load_op_library'}]
# map_fn : [{'args': [{'name': 'fn', 'kwarg': False, 'opt': False}, {'name': 'elems', 'kwarg': False, 'opt': False}, {'name': 'dtype', 'kwarg': True, 'opt': True}, {'name': 'parallel_iterations', 'kwarg': True, 'opt': True}, {'name': 'back_prop', 'kwarg': True, 'opt': True}, {'name': 'swap_memory', 'kwarg': True, 'opt': True}, {'name': 'infer_shape', 'kwarg': True, 'opt': True}, {'name': 'name', 'kwarg': True, 'opt': True}], 'attrs': ['tf', 'map_fn'], 'name': 'map_fn'}]
# ...

# %%
"""Extract nested values from a JSON tree."""


def json_extract(obj, key):
    """Recursively fetch values from nested JSON."""
    arr = []

    def extract(obj, arr, key):
        """Recursively search for values of key in JSON tree."""
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, (dict, list)):
                    extract(v, arr, key)
                elif k == key:
                    arr.append(v)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, key)
        return arr

    values = extract(obj, arr, key)
    return values

# %%
# Find every instance of `name` in a Python dictionary.
names = json_extract(tf, 'name')
print(names)
# Out:
# ['library_filename', 'load_op_library', 'fn', 'elems', 'dtype', 'parallel_iterations', 'back_prop', 'swap_memory', 'infer_shape', 'name', 'map_fn', 'start', 'stop', 'num', 'name', 'linspace', 'x', 'is_tensor', 'tensor', 'make_ndarray', 'library_location', 'load_library', 'values', 'dtype', 'shape', 'verify_shape', 'allow_broadcast', 'make_tensor_proto', 'input', 'name', 'identity_n', 'values', 'indices', 'dense_shape', 'IndexedSlices', 'shape', 'dtype', 'indices_dtype', 'dense_shape_dtype', 'indices_shape', 'IndexedSlicesSpec', 'ys', 'xs', 'gate_gradients', 'aggregation_method', 'name', 'hessians', '', '', 'jit_scope', 'values', 'value_range', 'nbins', 'dtype', 'name', 'histogram_fixed_width_bins', 'input', 'name', 'identity', 'values', 'value_range', 'nbins', 'dtype', 'name', 'histogram_fixed_width', 'computation', 'inputs', 'compile', 'opt', 'loss_scale', 'enable_mixed_precision_graph_rewrite', 'disable_mixed_precision_graph_rewrite', 'ckpt_dir_or_file', 'name', 'load_variable', 'c
# ...
